# %% [markdown]
# ## **Install and Import Dependencies**

# %%
# !pip install openbharatocr
# Out:
# Requirement already satisfied: openbharatocr in /usr/local/lib/python3.12/dist-packages (0.4.3)
# Requirement already satisfied: pytesseract==0.3.10 in /usr/local/lib/python3.12/dist-packages (from openbharatocr) (0.3.10)
# Requirement already satisfied: opencv-python==4.6.0.66 in /usr/local/lib/python3.12/dist-packages (from openbharatocr) (4.6.0.66)
# Requirement already satisfied: easyocr==1.7.1 in /usr/local/lib/python3.12/dist-packages (from openbharatocr) (1.7.1)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (from openbharatocr) (1.26.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from easyocr==1.7.1->openbharatocr) (2.9.0+cu128)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.12/dist-packages (from easyocr==1.7.1->openbharatocr) (0.24.0+cu128)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from easyocr==1.7.1->openbharatocr) (4.11.0.86)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from easyocr==1.7.1->openbharatocr) (1.16.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from easyocr==1.7.1->openbharatocr) (11.3.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from easyocr==1.7.1->openbharatocr) (0.25.2)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.12/dist-packages (from easyocr==1.7.1->openbharatocr) (0.6.7)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from easyocr==1.7.1->openbharatocr) (6.0.3)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from easyocr==1.7.1->openbharatocr) (2.1.2)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.12/dist-packages (from easyocr==1.7.1->openbharatocr) (1.4.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from easyocr==1.7.1->openbharatocr) (1.13.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from pytesseract==0.3.10->openbharatocr) (26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr==1.7.1->openbharatocr) (3.5.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr==1.7.1->openbharatocr) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr==1.7.1->openbharatocr) (2026.1.28)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr==1.7.1->openbharatocr) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->easyocr==1.7.1->openbharatocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->easyocr==1.7.1->openbharatocr) (3.0.3)

# %%
import openbharatocr

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## **Read in Images**

# %%
Image_path = '/content/Screenshot 2026-02-08 183118.png'

# %%
# Front side
front_result = openbharatocr.front_aadhaar(Image_path)
# Returns: {'name': str, 'dob': str, 'gender': str, 'aadhaar_number': str}

# %%
front_result
# Out:
# {'Full Name': 'Mehboob Rajput',
#  'Date/Year of Birth': '23/03/1981',
#  'Gender': 'Male',
#  'Aadhaar Number': '3900 5130 7206'}

# %% [markdown]
# ## **Draw Results**

# %%
img = cv2.imread(Image_path)

# Extract Aadhaar details
front_result = openbharatocr.front_aadhaar(Image_path)

font = cv2.FONT_HERSHEY_SIMPLEX
color = (255,0,0)
thickness = 2

y = 40
line_gap = 40

for key, value in front_result.items():
    text = f"{key.capitalize()}: {value}"
    cv2.putText(img, text, (20, y), font, 0.9, color, thickness, cv2.LINE_AA)
    y += line_gap

plt.figure(figsize=(7, 7))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
